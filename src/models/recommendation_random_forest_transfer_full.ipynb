# %% [markdown]
# # Category Recomendation Random Forest Transfer
# ---

# %%
# imports
import json
import time
import random
import joblib
import matplotlib.pyplot as plt
import itertools
import functools

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import top_k_accuracy_score, label_ranking_average_precision_score

# %%
data_path : str = "./dataset/"
models_path : str = "../web/models/transfer"
cities =  ["Burgos", "León", "Palencia", "Salamanca", "Valladolid"]

# %%
def mean_reciprocal_rank(real_categories, category_probs, categories) -> float:
    mrr: float = 0
    sample_size = len(category_probs)

    for real, probs in zip(real_categories, category_probs):
        ranking: list = [[category, prob]
                         for category, prob in zip(categories, probs)]
        ranking.sort(key=lambda x: x[1], reverse=True)

        for index, prob in enumerate(ranking, start=1):
            if prob[0] == real:
                mrr += 1/index
                break

    return mrr/sample_size

# %%
def construct_dataset(data_path: str, city: str) -> dict:


    # Abrimos el fichero de datos y lo convertimos a un dataframe
    with open(f"{data_path}Q_{city}.json", "r") as file:
        data = json.load(file)
    df = pd.json_normalize(data)

    # Separamos en dataframes de atributos y etiquetas
    X= df.drop('Categoria', axis=1)
    Y = df['Categoria']



    return X, Y

# %%
def get_intersection(i,j):
    return np.intersect1d(i.unique(),j.unique())

# %%
cities_dict = dict()

vals = []
for city in cities:
    x, y = construct_dataset(data_path,city)

    vals.append(y)

# %%
interseccion = functools.reduce(np.intersect1d, vals)

print(len(interseccion))
print(interseccion)
# Out:
# 71
# ['Alcohol' 'Bakery' 'Bank' 'Bar' 'Beauty' 'Bed' 'Bicycle' 'Bicycle_rental'
#  'Books' 'Butcher' 'Cafe' 'Car' 'Car_parts' 'Car_repair'
#  'Charging_station' 'Chemist' 'Childcare' 'Clinic' 'Clothes'
#  'Community_centre' 'Computer' 'Confectionery' 'Convenience' 'Copyshop'
#  'Curtain' 'Dentist' 'Doityourself' 'Driving_school' 'Fast_food' 'Florist'
#  'Fountain' 'Fuel' 'Furniture' 'Gift' 'Greengrocer' 'Hairdresser'
#  'Hardware' 'Ice_cream' 'Jewelry' 'Kiosk' 'Language_school' 'Laundry'
#  'Library' 'Lottery' 'Mobile_phone' 'Nightclub' 'Optician' 'Parking'
#  'Pastry' 'Perfumery' 'Pet' 'Pharmacy' 'Photo' 'Place_of_worship'
#  'Post_office' 'Pub' 'Restaurant' 'School' 'Seafood' 'Shoes'
#  'Social_centre' 'Social_facility' 'Sports' 'Supermarket' 'Taxi' 'Tobacco'
#  'Toilets' 'Travel_agency' 'University' 'Variety_store' 'Veterinary']

# %%
with open(f"{data_path}Q_Burgos.json", "r") as file:
    data = json.load(file)
    print(type(data))


dataset_final = []

for city in cities:
    with open(f"{data_path}Q_{city}.json", "r") as file:
        data = json.load(file)

    for entry in data:
        new_entry = {}
        if entry["Categoria"] not in interseccion:
            continue
        new_entry["Categoria"] = entry["Categoria"]
        new_entry_indices = dict()
        for cat, val in entry["QualityIndices"].items():
            if cat in interseccion:
                new_entry_indices[cat] = val
        new_entry["QualityIndices"] = new_entry_indices
        dataset_final.append(new_entry)
# Out:
# <class 'list'>

# %%
df = pd.json_normalize(dataset_final)

print(df.shape)
df.head()
# Out:
# (10400, 285)
#        Categoria  QualityIndices.Chemist.Qjensen_raw  \
# 0   Mobile_phone                           35.068196
# 1  Variety_store                           -1.213434
# 2        Clothes                           -6.343462
# 3    Supermarket                           -5.596865
# 4    Supermarket                           -3.912906
#
#    QualityIndices.Chemist.Qjensen  QualityIndices.Chemist.Qperm  \
# 0                       23.386799                    322.537765
# 1                      -12.894830                    -93.116073
# 2                      -18.024858                     98.314612
# 3                      -17.278262                   -109.785012
# 4                      -15.594302                   -146.032177
#
#    QualityIndices.Chemist.Qperm_raw  QualityIndices.Jewelry.Qjensen_raw  \
# 0                        552.356647                           21.683910
# 1                        136.702809                            0.870369
# 2                        328.133495                           34.819324
# 3                        120.033870                          -12.726443
# 4                         83.786706                          -15.984806
#
#    QualityIndices.Jewelry.Qjensen  QualityIndices.Jewelry.Qperm  \
# 0                        4.536842                    252.502075
# 1                      -16.276699                   -163.125833
# 2                       17.672256                    331.074057
# 3                      -29.873511                   -206.578592
# 4                      -33.131874                   -255.922506
#
#    QualityIndices.Jewelry.Qperm_raw  QualityIndices.Confectionery.Qjensen_raw  \
# 0                        562.010170                                  7.758976
# 1                        146.382262                                 -0.157266
# 2                        640.582152                                  9.069019
# 3                        102.929503                                  0.030916
# 4                         53.585589                                  4.163730
#
#    ...  QualityIndices.Doityourself.Qperm  \
# 0  ...                        -106.678484
# 1  ...                         -64.203915
# 2  ...                        -163.262388
# 3  ...                         -67.446453
# 4  ...                         -52.317903
#
#    QualityIndices.Doityourself.Qperm_raw  \
# 0                            -111.034128
# 1                             -68.559558
# 2                            -167.618032
# 3                             -71.802097
# 4                             -56.673547
#
#    QualityIndices.Driving_school.Qjensen_raw  \
# 0                                 -27.590111
# 1                                  -2.966233
# 2                                 -31.564610
# 3                                  -9.723039
# 4                                  -1.259314
#
#    QualityIndices.Driving_school.Qjensen  QualityIndices.Driving_school.Qperm  \
# 0                             -32.726310                           -35.577908
# 1                              -8.102432                            18.573371
# 2                             -36.700810                          -127.834190
# 3                             -14.859238                            28.472999
# 4                              -6.395514                            24.783156
#
#    QualityIndices.Driving_school.Qperm_raw  QualityIndices.Fuel.Qjensen_raw  \
# 0                                -8.381273                      -117.881834
# 1                                45.770006                      -141.511843
# 2                              -100.637555                       -72.998346
# 3                                55.669634                      -161.038041
# 4                                51.979791                      -131.633963
#
#    QualityIndices.Fuel.Qjensen  QualityIndices.Fuel.Qperm  \
# 0                  -118.956658                -145.753964
# 1                  -142.586667                 -99.146958
# 2                   -74.073170                -254.133417
# 3                  -162.112865                -116.615563
# 4                  -132.708787                 -91.842626
#
#    QualityIndices.Fuel.Qperm_raw
# 0                    -153.834858
# 1                    -107.227851
# 2                    -262.214310
# 3                    -124.696456
# 4                     -99.923519
#
# [5 rows x 285 columns]

# %%
def cross_validate_random_forest(dataframe, k=5, **kwargs):

    # Creamos el objeto para KFold para hacer validación cruzada
    kf = KFold(n_splits=k, shuffle=True, random_state=random.randint(0, 100))

    # Dataframes de atributos y etiquetas
    X= dataframe.drop('Categoria', axis=1)
    Y = dataframe['Categoria']


    folds_mrr = []

    for n_fold, (train, test) in enumerate(kf.split(X), start=1):
        print(f">>> Fold: {n_fold}")
        classifier = RandomForestClassifier(n_estimators=100, n_jobs=-1)
        fold_time = time.time()


        # Definimos conjunto de test
        df_train_x = X.iloc[train]
        df_train_y = Y.iloc[train]

        # Definimos conjunto de test
        df_test_x = X.iloc[test]
        df_test_y = Y.iloc[test]

        # Entrenamos el modelo
        classifier.fit(df_train_x, df_train_y)

        # Predicciones
        preds = classifier.predict_proba(df_test_x)

        # Calculamos el MRR
        mrr = mean_reciprocal_rank(df_test_y, preds, classifier.classes_)
        folds_mrr.append(mrr)
        print(f"> MRR: {mrr}")
        print(f"> Tiempo fold {n_fold}: {time.time() - fold_time :.1f} s")

    return folds_mrr

# %%
folds = cross_validate_random_forest(df, k=100)
# Out:
# >>> Fold: 1
# > MRR: 0.2978938131188381
# > Tiempo fold 1: 10.8 s
# >>> Fold: 2
# > MRR: 0.2580832233210591
# > Tiempo fold 2: 11.0 s
# >>> Fold: 3
# > MRR: 0.3201337795153505
# > Tiempo fold 3: 10.7 s
# >>> Fold: 4
# > MRR: 0.34956502675727114
# > Tiempo fold 4: 10.6 s
# >>> Fold: 5
# > MRR: 0.33812269262254485
# > Tiempo fold 5: 10.9 s
# >>> Fold: 6
# > MRR: 0.29346325314856236
# > Tiempo fold 6: 10.9 s
# >>> Fold: 7
# > MRR: 0.2553371563964119
# > Tiempo fold 7: 10.8 s
# >>> Fold: 8
# > MRR: 0.2524699422313741
# > Tiempo fold 8: 11.2 s
# >>> Fold: 9
# > MRR: 0.32617029304964007
# > Tiempo fold 9: 11.2 s
# >>> Fold: 10
# > MRR: 0.3520069267823516
# > Tiempo fold 10: 11.0 s
# >>> Fold: 11
# > MRR: 0.35380452298174564
# > Tiempo fold 11: 11.2 s
# >>> Fold: 12
# > MRR: 0.28272822203129705
# > Tiempo fold 12: 10.8 s
# >>> Fold: 13
# > MRR: 0.2730577653553351
# > Tiempo fold 13: 11.0 s
# >>> Fold: 14
# > MRR: 0.3129068829336174
# > Tiempo fold 14: 11.0 s
# >>> Fold: 15
# > MRR: 0.33697094306925107
# > Tiempo fold 15: 10.9 s
# >>> Fold: 16
# > MRR: 0.3719013954868018
# > Tiempo fold 16: 10.7 s
# >>> Fold: 17
# > MRR: 0.3603552909508053
# > Tiempo fold 17: 10.5 s
# >>> Fold: 18
# > MRR: 0.33663367892040913
# > Tiempo fold 18: 10.7 s
# >>> Fold: 19
# > MRR: 0.2787839483362179
# > Tiempo fold 19: 11.2 s
# >>> Fold: 20
# > MRR: 0.30983547600041306
# > Tiempo fold 20: 10.7 s
# >>> Fold: 21
# > MRR: 0.303817083804812
# > Tiempo fold 21: 10.5 s
# >>> Fold: 22
# > MRR: 0.36962681605457787
# > Tiempo fold 22: 11.0 s
# >>> Fold: 23
# > MRR: 0.29261563528284384
# > Tiempo fold 23: 10.5 s
# >>> Fold: 24
# > MRR: 0.37015577293270024
# > Tiempo fold 24: 10.8 s
# >>> Fold: 25
# > MRR: 0.39099660897003763
# > Tiempo fold 25: 10.7 s
# >>> Fold: 26
# > MRR: 0.3300228613151311
# > Tiempo fold 26: 10.9 s
# >>> Fold: 27
# > MRR: 0.290134116947021
# > Tiempo fold 27: 10.5 s
# >>> Fold: 28
# > MRR: 0.3375232795807331
# > Tiempo fold 28: 10.8 s
# >>> Fold: 29
# > MRR: 0.3282814423737156
# > Tiempo fold 29: 11.0 s
# >>> Fold: 30
# > MRR: 0.38944778881765796
# > Tiempo fold 30: 10.6 s
# >>> Fold: 31
# > MRR: 0.3362218925640739
# > Tiempo fold 31: 10.4 s
# >>> Fold: 32
# > MRR: 0.2875151520904206
# > Tiempo fold 32: 11.2 s
# >>> Fold: 33
# > MRR: 0.3366861609777066
# > Tiempo fold 33: 11.0 s
# >>> Fold: 34
# > MRR: 0.32532799275301766
# > Tiempo fold 34: 11.3 s
# >>> Fold: 35
# > MRR: 0.33341267898405774
# > Tiempo fold 35: 10.9 s
# >>> Fold: 36
# > MRR: 0.27863167134067895
# > Tiempo fold 36: 10.9 s
# >>> Fold: 37
# > MRR: 0.2786288652066827
# > Tiempo fold 37: 10.7 s
# >>> Fold: 38
# > MRR: 0.2527072539456837
# > Tiempo fold 38: 10.6 s
# >>> Fold: 39
# > MRR: 0.31417248593153285
# > Tiempo fold 39: 10.9 s
# >>> Fold: 40
# > MRR: 0.32531494300953084
# > Tiempo fold 40: 10.9 s
# >>> Fold: 41
# > MRR: 0.34031397601400126
# > Tiempo fold 41: 10.6 s
# >>> Fold: 42
# > MRR: 0.310873434347978
# > Tiempo fold 42: 11.0 s
# >>> Fold: 43
# > MRR: 0.27045062444319784
# > Tiempo fold 43: 10.6 s
# >>> Fold: 44
# > MRR: 0.3043539617458703
# > Tiempo fold 44: 10.6 s
# >>> Fold: 45
# > MRR: 0.30561847553451815
# > Tiempo fold 45: 10.6 s
# >>> Fold: 46
# > MRR: 0.24735666221039837
# > Tiempo fold 46: 10.6 s
# >>> Fold: 47
# > MRR: 0.3045769228822626
# > Tiempo fold 47: 11.5 s
# >>> Fold: 48
# > MRR: 0.2748641264428539
# > Tiempo fold 48: 10.9 s
# >>> Fold: 49
# > MRR: 0.32776979063760386
# > Tiempo fold 49: 10.5 s
# >>> Fold: 50
# > MRR: 0.25944467797591886
# > Tiempo fold 50: 10.9 s
# >>> Fold: 51
# > MRR: 0.3453829651946967
# > Tiempo fold 51: 10.6 s
# >>> Fold: 52
# > MRR: 0.2595591439091768
# > Tiempo fold 52: 10.5 s
# >>> Fold: 53
# > MRR: 0.2998095680354979
# > Tiempo fold 53: 11.6 s
# >>> Fold: 54
# > MRR: 0.2761009171115399
# > Tiempo fold 54: 11.2 s
# >>> Fold: 55
# > MRR: 0.26056449600795484
# > Tiempo fold 55: 10.5 s
# >>> Fold: 56
# > MRR: 0.29436396466427833
# > Tiempo fold 56: 10.8 s
# >>> Fold: 57
# > MRR: 0.3094346591839245
# > Tiempo fold 57: 10.7 s
# >>> Fold: 58
# > MRR: 0.3103714919365199
# > Tiempo fold 58: 10.8 s
# >>> Fold: 59
# > MRR: 0.27634719268107166
# > Tiempo fold 59: 10.6 s
# >>> Fold: 60
# > MRR: 0.3317614321785181
# > Tiempo fold 60: 10.8 s
# >>> Fold: 61
# > MRR: 0.35856346194931976
# > Tiempo fold 61: 11.2 s
# >>> Fold: 62
# > MRR: 0.26964641128515254
# > Tiempo fold 62: 10.8 s
# >>> Fold: 63
# > MRR: 0.26301063033932215
# > Tiempo fold 63: 10.6 s
# >>> Fold: 64
# > MRR: 0.260150149405854
# > Tiempo fold 64: 10.6 s
# >>> Fold: 65
# > MRR: 0.25983788291525595
# > Tiempo fold 65: 10.8 s
# >>> Fold: 66
# > MRR: 0.2457941296149566
# > Tiempo fold 66: 10.6 s
# >>> Fold: 67
# > MRR: 0.2558927247520052
# > Tiempo fold 67: 10.7 s
# >>> Fold: 68
# > MRR: 0.3021083668276037
# > Tiempo fold 68: 10.8 s
# >>> Fold: 69
# > MRR: 0.2710328594178566
# > Tiempo fold 69: 10.6 s
# >>> Fold: 70
# > MRR: 0.337510643816005
# > Tiempo fold 70: 10.6 s
# >>> Fold: 71
# > MRR: 0.28502092024129305
# > Tiempo fold 71: 10.8 s
# >>> Fold: 72
# > MRR: 0.3204893011924002
# > Tiempo fold 72: 10.7 s
# >>> Fold: 73
# > MRR: 0.321080001717194
# > Tiempo fold 73: 10.6 s
# >>> Fold: 74
# > MRR: 0.25648772242061274
# > Tiempo fold 74: 10.9 s
# >>> Fold: 75
# > MRR: 0.34471313490527844
# > Tiempo fold 75: 10.8 s
# >>> Fold: 76
# > MRR: 0.3437055118418994
# > Tiempo fold 76: 10.5 s
# >>> Fold: 77
# > MRR: 0.3222336446522406
# > Tiempo fold 77: 10.6 s
# >>> Fold: 78
# > MRR: 0.3284352647468819
# > Tiempo fold 78: 11.0 s
# >>> Fold: 79
# > MRR: 0.2877777670965869
# > Tiempo fold 79: 10.7 s
# >>> Fold: 80
# > MRR: 0.2625025177507213
# > Tiempo fold 80: 10.7 s
# >>> Fold: 81
# > MRR: 0.3403708224805787
# > Tiempo fold 81: 10.9 s
# >>> Fold: 82
# > MRR: 0.26515728412730855
# > Tiempo fold 82: 10.9 s
# >>> Fold: 83
# > MRR: 0.26077469002469755
# > Tiempo fold 83: 10.7 s
# >>> Fold: 84
# > MRR: 0.25251339492040614
# > Tiempo fold 84: 10.9 s
# >>> Fold: 85
# > MRR: 0.30046151267480925
# > Tiempo fold 85: 10.7 s
# >>> Fold: 86
# > MRR: 0.34930661795411555
# > Tiempo fold 86: 10.5 s
# >>> Fold: 87
# > MRR: 0.258115389418056
# > Tiempo fold 87: 10.8 s
# >>> Fold: 88
# > MRR: 0.3027215481673296
# > Tiempo fold 88: 10.8 s
# >>> Fold: 89
# > MRR: 0.31924071365471557
# > Tiempo fold 89: 10.8 s
# >>> Fold: 90
# > MRR: 0.29282649869580973
# > Tiempo fold 90: 10.6 s
# >>> Fold: 91
# > MRR: 0.32755903801804387
# > Tiempo fold 91: 10.8 s
# >>> Fold: 92
# > MRR: 0.33567403571748183
# > Tiempo fold 92: 10.9 s
# >>> Fold: 93
# > MRR: 0.2861892747317957
# > Tiempo fold 93: 11.0 s
# >>> Fold: 94
# > MRR: 0.3495373087963147
# > Tiempo fold 94: 10.5 s
# >>> Fold: 95
# > MRR: 0.2868169024175413
# > Tiempo fold 95: 10.7 s
# >>> Fold: 96
# > MRR: 0.3470990602872825
# > Tiempo fold 96: 10.8 s
# >>> Fold: 97
# > MRR: 0.31000719987854014
# > Tiempo fold 97: 10.9 s
# >>> Fold: 98
# > MRR: 0.2169862833607394
# > Tiempo fold 98: 10.9 s
# >>> Fold: 99
# > MRR: 0.3065902675710191
# > Tiempo fold 99: 10.7 s
# >>> Fold: 100
# > MRR: 0.2754342247451731
# > Tiempo fold 100: 10.8 s

# %%
print(np.mean(folds))
# Out:
# 0.30520158333559894

# %%
def train_model(df):
    train_time = time.time()


    # Dataframes de atributos y etiquetas
    df_attr = df.drop('Categoria', axis=1)
    df_y = df['Categoria']

    classifier = RandomForestClassifier(n_estimators=100, n_jobs=-1)

    classifier.fit(df_attr, df_y)
    print(f"> Tiempo train: {time.time() - train_time :.1f} s")

    joblib.dump(classifier, f"{models_path}/transfer.gz", compress=9)

# %%
train_model(df)
# Out:
# > Tiempo train: 10.7 s
